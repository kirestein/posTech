# %% [markdown]
# # DataFrame

# %%
import pandas as pd

# %%
df1 = pd.DataFrame({'A': {'X': 1}, 'B': {'X': 2}})
df2 = pd.DataFrame({'C': {'X': 3}, 'D': {'X': 2}})
pd.concat([df1, df2])
# Out:
#      A    B    C    D
# X  1.0  2.0  NaN  NaN
# X  NaN  NaN  3.0  2.0

# %%
dados = [('A', 'B'), ('C', 'D')]
df = pd.DataFrame(dados, columns = ['L1', 'L2'])
df
# Out:
#   L1 L2
# 0  A  B
# 1  C  D

# %% [markdown]
# ## Determinando Seleções

# %%
import pandas as pd

numeros = [i for i in range(11)]
letras = [chr(i + 65) for i in range(11)]
nome_coluna = ['N']

df = pd.DataFrame(data = numeros, index = letras, columns = nome_coluna)
df
# Out:
#     N
# A   0
# B   1
# C   2
# D   3
# E   4
# F   5
# G   6
# H   7
# I   8
# J   9
# K  10

# %%
selecao = df['N'].isin([i for i in range(11) if i % 2 == 0])
df = df[selecao]
df
# Out:
#     N
# A   0
# C   2
# E   4
# G   6
# I   8
# K  10

# %%
data = [[9,6,3], [8, 5, 2], [7,4,1]]
data
# Out:
# [[9, 6, 3], [8, 5, 2], [7, 4, 1]]

# %%
lines = list('ZYX')
columns = list('CBA')

# %%
df = pd.DataFrame(data, lines, columns)
df
# Out:
#    C  B  A
# Z  9  6  3
# Y  8  5  2
# X  7  4  1

# %%
df.sort_index()
df.sort_index(axis = 1)
df
# Out:
#    C  B  A
# Z  9  6  3
# Y  8  5  2
# X  7  4  1

# %%
dados_A = [['Ary', 'M', 21], ['Cátia', 'F', 19], ['Carlos', 'M', 50], ['Beto', 'M', 29], ['Bruna', 'F', 31], ['Ana', 'F', 42]]
dados_A
# Out:
# [['Ary', 'M', 21],
#  ['Cátia', 'F', 19],
#  ['Carlos', 'M', 50],
#  ['Beto', 'M', 29],
#  ['Bruna', 'F', 31],
#  ['Ana', 'F', 42]]

# %%
df_A = pd.DataFrame(dados_A, list('012345'), ['Nome', 'Sexo', 'Idade'])
df_A
# Out:
#      Nome Sexo  Idade
# 0     Ary    M     21
# 1   Cátia    F     19
# 2  Carlos    M     50
# 3    Beto    M     29
# 4   Bruna    F     31
# 5     Ana    F     42

# %%
df_B = df_A.sort_values(by = ['Nome', 'Sexo'], inplace=True)

# %%
df_B

# %%
df_B = df_A.sort_values(by = ['Sexo', 'Nome'], inplace=True)

# %%
df_B

# %%
df_B = df_A.sort_values(by = ['Sexo', 'Nome'])

# %%
df_B
# Out:
#      Nome Sexo  Idade
# 5     Ana    F     42
# 4   Bruna    F     31
# 1   Cátia    F     19
# 0     Ary    M     21
# 3    Beto    M     29
# 2  Carlos    M     50

# %% [markdown]
# ## Formas de Seleção

# %%
import pandas as pd
alunos = pd.DataFrame({'Nome': ['Ary', 'Cátia', 'Denis', 'Beto', 'Bruna', 'Dara', 'Carlos', 'Alice'], 
                        'Sexo': ['M', 'F', 'M', 'M', 'F', 'F', 'M', 'F'], 
                        'Idade': [15, 27, 56, 32, 42, 21, 19, 35], 
                        'Notas': [7.5, 2.5, 5.0, 10, 8.2, 7, 6, 5.6], 
                        'Aprovado': [True, False, False, True, True, True, False, False]}, 
                        columns = ['Nome', 'Idade', 'Sexo', 'Notas', 'Aprovado'])

# %%
alunos
# Out:
#      Nome  Idade Sexo  Notas  Aprovado
# 0     Ary     15    M    7.5      True
# 1   Cátia     27    F    2.5     False
# 2   Denis     56    M    5.0     False
# 3    Beto     32    M   10.0      True
# 4   Bruna     42    F    8.2      True
# 5    Dara     21    F    7.0      True
# 6  Carlos     19    M    6.0     False
# 7   Alice     35    F    5.6     False

# %%
select = alunos['Aprovado'] == True
aprovados = alunos[select]
aprovados
# Out:
#     Nome  Idade Sexo  Notas  Aprovado
# 0    Ary     15    M    7.5      True
# 3   Beto     32    M   10.0      True
# 4  Bruna     42    F    8.2      True
# 5   Dara     21    F    7.0      True

# %%
select = (alunos['Aprovado'] == True) & (alunos['Sexo'] == 'F')
aprovadas = alunos[select]
aprovadas
# Out:
#     Nome  Idade Sexo  Notas  Aprovado
# 4  Bruna     42    F    8.2      True
# 5   Dara     21    F    7.0      True

# %%
select = ((alunos['Idade'] > 10) & (alunos['Idade'] < 20)) | (alunos['Idade'] >= 40)
alunos_selecionados = alunos[select]
alunos_selecionados
# Out:
#      Nome  Idade Sexo  Notas  Aprovado
# 0     Ary     15    M    7.5      True
# 2   Denis     56    M    5.0     False
# 4   Bruna     42    F    8.2      True
# 6  Carlos     19    M    6.0     False

# %%
alunos
# Out:
#      Nome  Idade Sexo  Notas  Aprovado
# 0     Ary     15    M    7.5      True
# 1   Cátia     27    F    2.5     False
# 2   Denis     56    M    5.0     False
# 3    Beto     32    M   10.0      True
# 4   Bruna     42    F    8.2      True
# 5    Dara     21    F    7.0      True
# 6  Carlos     19    M    6.0     False
# 7   Alice     35    F    5.6     False

# %%
select = alunos['Aprovado'] == False
reprovados = alunos.loc[select][['Nome', 'Sexo', 'Idade']]
reprovados
# Out:
#      Nome Sexo  Idade
# 1   Cátia    F     27
# 2   Denis    M     56
# 6  Carlos    M     19
# 7   Alice    F     35

# %%
alunos.sort_values(by = ['Idade'], inplace = True)
alunos.iloc[:3]
# Out:
#      Nome  Idade Sexo  Notas  Aprovado
# 0     Ary     15    M    7.5      True
# 6  Carlos     19    M    6.0     False
# 5    Dara     21    F    7.0      True

# %% [markdown]
# ## Trabalhando com dados faltantes

# %%
imoveis = pd.DataFrame([['Apartamento', None, 970, 68], 
                        ['Apartamento', 2000, 878, 112], 
                        ['Casa', 5000, None, 500], 
                        ['Apartamento', None, 1010, 170], 
                        ['Apartamento', 1500, 850, None], 
                        ['Casa', None, None, None], 
                        ['Apartamento', 2000, 878, None], 
                        ['Apartamento', 1550, None, 228], 
                        ['Apartamento', 2500, 880, 195]], 
                        columns = ['Tipo', 'Valor', 'Condominio', 'IPTU'])

# %%
imoveis
# Out:
#           Tipo   Valor  Condominio   IPTU
# 0  Apartamento     NaN       970.0   68.0
# 1  Apartamento  2000.0       878.0  112.0
# 2         Casa  5000.0         NaN  500.0
# 3  Apartamento     NaN      1010.0  170.0
# 4  Apartamento  1500.0       850.0    NaN
# 5         Casa     NaN         NaN    NaN
# 6  Apartamento  2000.0       878.0    NaN
# 7  Apartamento  1550.0         NaN  228.0
# 8  Apartamento  2500.0       880.0  195.0

# %%
imoveis.dropna(subset=['Valor'], inplace=True)

# %%
imoveis
# Out:
#           Tipo   Valor  Condominio   IPTU
# 1  Apartamento  2000.0       878.0  112.0
# 2         Casa  5000.0         NaN  500.0
# 4  Apartamento  1500.0       850.0    NaN
# 6  Apartamento  2000.0       878.0    NaN
# 7  Apartamento  1550.0         NaN  228.0
# 8  Apartamento  2500.0       880.0  195.0

# %%
selecao = (imoveis['Tipo'] == 'Apartamento') & (imoveis['Condominio'].isnull())
imoveis = imoveis[selecao]
imoveis
# Out:
#           Tipo   Valor  Condominio   IPTU
# 7  Apartamento  1550.0         NaN  228.0

# %%
imoveis = imoveis.fillna({'Condominio': 0, 'IPTU': 0})
imoveis
# Out:
#           Tipo   Valor  Condominio   IPTU
# 7  Apartamento  1550.0         0.0  228.0

# %%
imoveis.index = range(imoveis.shape[0])
imoveis
# Out:
#           Tipo   Valor  Condominio   IPTU
# 0  Apartamento  1550.0         0.0  228.0

# %%
atletas = pd.DataFrame([['Marcos', 9.62], ['Pedro', None], ['João', 9.69], 
                        ['Beto', 9.72], ['Sandro', None], ['Denis', 9.69], 
                        ['Ary', None], ['Carlos', 9.74]], 
                        columns = ['Corredor', 'Melhor Tempo'])
atletas
# Out:
#   Corredor  Melhor Tempo
# 0   Marcos          9.62
# 1    Pedro           NaN
# 2     João          9.69
# 3     Beto          9.72
# 4   Sandro           NaN
# 5    Denis          9.69
# 6      Ary           NaN
# 7   Carlos          9.74

# %%
atletas.fillna(atletas['Melhor Tempo'].mean(), inplace = True)

# %%
atletas
# Out:
#   Corredor  Melhor Tempo
# 0   Marcos         9.620
# 1    Pedro         9.692
# 2     João         9.690
# 3     Beto         9.720
# 4   Sandro         9.692
# 5    Denis         9.690
# 6      Ary         9.692
# 7   Carlos         9.740

# %% [markdown]
# ## Criando Variáveis

# %%
import pandas as pd
alunos = pd.DataFrame({'Nome': ['Ary', 'Cátia', 'Denis', 'Beto', 'Bruna', 'Dara', 'Carlos', 'Alice'], 
                        'Sexo': ['M', 'F', 'M', 'M', 'F', 'F', 'M', 'F'], 
                        'Idade': [15, 27, 56, 32, 42, 21, 19, 35], 
                        'Notas': [7.5, 2.5, 5.0, 10, 8.2, 7, 6, 5.6]}, 
                        columns = ['Nome', 'Idade', 'Sexo', 'Notas'])

# %%
alunos
# Out:
#      Nome  Idade Sexo  Notas
# 0     Ary     15    M    7.5
# 1   Cátia     27    F    2.5
# 2   Denis     56    M    5.0
# 3    Beto     32    M   10.0
# 4   Bruna     42    F    8.2
# 5    Dara     21    F    7.0
# 6  Carlos     19    M    6.0
# 7   Alice     35    F    5.6

# %%
alunos['Medias'] = alunos['Notas'].apply(lambda x: x - alunos['Notas'].mean())
alunos
# Out:
#      Nome  Idade Sexo  Notas  Medias
# 0     Ary     15    M    7.5   1.025
# 1   Cátia     27    F    2.5  -3.975
# 2   Denis     56    M    5.0  -1.475
# 3    Beto     32    M   10.0   3.525
# 4   Bruna     42    F    8.2   1.725
# 5    Dara     21    F    7.0   0.525
# 6  Carlos     19    M    6.0  -0.475
# 7   Alice     35    F    5.6  -0.875

# %%
alunos['Faixa Etária'] = alunos['Idade'].apply(lambda x: 'Menor que 20' if x < 20 else ('Entre 20 e 40 anos') if (x >= 20 and x <= 40) else 'Maior que 40 anos') 
alunos
# Out:
#      Nome  Idade Sexo  Notas  Medias        Faixa Etária
# 0     Ary     15    M    7.5   1.025        Menor que 20
# 1   Cátia     27    F    2.5  -3.975  Entre 20 e 40 anos
# 2   Denis     56    M    5.0  -1.475   Maior que 40 anos
# 3    Beto     32    M   10.0   3.525  Entre 20 e 40 anos
# 4   Bruna     42    F    8.2   1.725   Maior que 40 anos
# 5    Dara     21    F    7.0   0.525  Entre 20 e 40 anos
# 6  Carlos     19    M    6.0  -0.475        Menor que 20
# 7   Alice     35    F    5.6  -0.875  Entre 20 e 40 anos

# %% [markdown]
# ## contadores

# %%
import pandas as pd

# %%
m1 = 'CCcCCccCCCccCcCccCcCcCCCcCCcccCCcCcCcCcccCCcCcccCc'
m2 = 'CCCCCccCccCcCCCCccCccccCccCccCCcCccCcCcCCcCccCccCc'
m3 = 'CccCCccCcCCCCCCCCCCcccCccCCCCCCccCCCcccCCCcCCcccCC'
m4 = 'cCCccCCccCCccCCccccCcCcCcCcCcCcCCCCccccCCCcCCcCCCC'
m5 = 'CCCcCcCcCcCCCcCCcCcCCccCcCCcccCccCCcCcCcCcCcccccCc'

# %%
column = ["Faces"]
line = ["C", "c"]

# %%
eventos = {
    'm1': list(m1),
    'm2': list(m2),
    'm3': list(m3),
    'm4': list(m4),
    'm5': list(m5)
}
eventos
# Out:
# {'m1': ['C',
#   'C',
#   'c',
#   'C',
#   'C',
#   'c',
#   'c',
#   'C',
#   'C',
#   'C',
#   'c',
#   'c',
#   'C',
#   'c',
#   'C',
#   'c',
#   'c',
#   'C',
#   'c',
#   'C',
#   'c',
#   'C',
#   'C',
#   'C',
#   'c',
#   'C',
#   'C',
#   'c',
#   'c',
#   'c',
#   'C',
#   'C',
#   'c',
#   'C',
#   'c',
#   'C',
#   'c',
#   'C',
#   'c',
#   'c',
#   'c',
#   'C',
#   'C',
#   'c',
#   'C',
#   'c',
#   'c',
#   'c',
#   'C',
#   'c'],
#  'm2': ['C',
#   'C',
#   'C',
#   'C',
#   'C',
#   'c',
#   'c',
#   'C',
#   'c',
#   'c',
#   'C',
#   'c',
#   'C',
#   'C',
#   'C',
#   'C',
#   'c',
#   'c',
#   'C',
#   'c',
#   'c',
#   'c',
#   'c',
#   'C',
#   'c',
#   'c',
#   'C',
#   'c',
#   'c',
#   'C',
#   'C',
#   'c',
#   'C',
#   'c',
#   'c',
#   'C',
#   'c',
#   'C',
#   'c',
#   'C',
#   'C',
#   'c',
#   'C',
#   'c',
#   'c',
#   'C',
#   'c',
#   'c',
#   'C',
#   'c'],
#  'm3': ['C',
#   'c',
#   'c',
#   'C',
#   'C',
#   'c',
#   'c',
#   'C',
# ...

# %%
moedas = pd.DataFrame(eventos)
moedas
# Out:
#    m1 m2 m3 m4 m5
# 0   C  C  C  c  C
# 1   C  C  c  C  C
# 2   c  C  c  C  C
# 3   C  C  C  c  c
# 4   C  C  C  c  C
# 5   c  c  c  C  c
# 6   c  c  c  C  C
# 7   C  C  C  c  c
# 8   C  c  c  c  C
# 9   C  c  C  C  c
# 10  c  C  C  C  C
# 11  c  c  C  c  C
# 12  C  C  C  c  C
# 13  c  C  C  C  c
# 14  C  C  C  C  C
# 15  c  C  C  c  C
# 16  c  c  C  c  c
# 17  C  c  C  c  C
# 18  c  C  C  c  c
# 19  C  c  c  C  C
# 20  c  c  c  c  C
# 21  C  c  c  C  c
# 22  C  c  C  c  c
# 23  C  C  c  C  C
# 24  c  c  c  c  c
# 25  C  c  C  C  C
# 26  C  C  C  c  C
# 27  c  c  C  C  c
# 28  c  c  C  c  c
# 29  c  C  C  C  c
# 30  C  C  C  c  C
# 31  C  c  c  C  c
# 32  c  C  c  C  c
# 33  C  c  C  C  C
# 34  c  c  C  C  C
# 35  C  C  C  c  c
# 36  c  c  c  c  C
# 37  C  C  c  c  c
# 38  c  c  c  c  C
# 39  c  C  C  C  c
# 40  c  C  C  C  C
# 41  C  c  C  C  c
# 42  C  C  c  c  C
# 43  c  c  C  C  c
# 44  C  c  C  C  c
# 45  c  C  c  c  c
# 46  c  c  c  C  c
# 47  c  c  c  C  c
# 48  C  C  C  C  C
# ...

# %%
df = pd.DataFrame(data = ['Cara', 'Coroa'], index = ['c', 'C'], columns= ['Faces'])
df
# Out:
#    Faces
# c   Cara
# C  Coroa

# %%
for moeda in moedas:
    df = pd.concat([df, moedas[moeda].value_counts()], axis=1)
df
# Out:
#    Faces  m1  m2  m3  m4  m5
# c   Cara  25  26  19  23  25
# C  Coroa  25  24  31  27  25

# %% [markdown]
# ## Criando Agrupamentos

# %%
import pandas as pd
alunos = pd.DataFrame({'Nome': ['Ary', 'Cátia', 'Denis', 'Beto', 'Bruna', 'Dara', 'Carlos', 'Alice'], 
                        'Sexo': ['M', 'F', 'M', 'M', 'F', 'F', 'M', 'F'], 
                        'Idade': [15, 27, 56, 32, 42, 21, 19, 35], 
                        'Notas': [7.5, 2.5, 5.0, 10, 8.2, 7, 6, 5.6], 
                        'Aprovado': [True, False, False, True, True, True, False, False]}, 
                        columns = ['Nome', 'Idade', 'Sexo', 'Notas', 'Aprovado'])
alunos
# Out:
#      Nome  Idade Sexo  Notas  Aprovado
# 0     Ary     15    M    7.5      True
# 1   Cátia     27    F    2.5     False
# 2   Denis     56    M    5.0     False
# 3    Beto     32    M   10.0      True
# 4   Bruna     42    F    8.2      True
# 5    Dara     21    F    7.0      True
# 6  Carlos     19    M    6.0     False
# 7   Alice     35    F    5.6     False

# %%
sexo = alunos.groupby('Sexo')
sexo.groups
# Out:
# {'F': [1, 4, 5, 7], 'M': [0, 2, 3, 6]}

# %%
sexo = pd.DataFrame(sexo['Notas'].mean().round(2))
sexo.columns = ['Notas Médias']
sexo
# Out:
#       Notas Médias
# Sexo
# F             5.82
# M             7.12

# %% [markdown]
# ## Estatísticas Descritivas

# %%
import pandas as pd

# %%
precos = pd.DataFrame([['Feira', 'Cebola', 2.5], 
                        ['Mercado', 'Cebola', 1.99], 
                        ['Supermercado', 'Cebola', 1.69], 
                        ['Feira', 'Tomate', 4], 
                        ['Mercado', 'Tomate', 3.29], 
                        ['Supermercado', 'Tomate', 2.99], 
                        ['Feira', 'Batata', 4.2], 
                        ['Mercado', 'Batata', 3.99], 
                        ['Supermercado', 'Batata', 3.69]], 
                        columns = ['Local', 'Produto', 'Preço'])
precos
# Out:
#           Local Produto  Preço
# 0         Feira  Cebola   2.50
# 1       Mercado  Cebola   1.99
# 2  Supermercado  Cebola   1.69
# 3         Feira  Tomate   4.00
# 4       Mercado  Tomate   3.29
# 5  Supermercado  Tomate   2.99
# 6         Feira  Batata   4.20
# 7       Mercado  Batata   3.99
# 8  Supermercado  Batata   3.69

# %%
produtos = precos.groupby('Produto', sort = False)
produtos.describe().round(2)
# Out:
#         Preço
#         count  mean   std   min   25%   50%   75%  max
# Produto
# Cebola    3.0  2.06  0.41  1.69  1.84  1.99  2.24  2.5
# Tomate    3.0  3.43  0.52  2.99  3.14  3.29  3.64  4.0
# Batata    3.0  3.96  0.26  3.69  3.84  3.99  4.10  4.2

# %% [markdown]
# ## Identificando e Removendo Outliers

# %%
import pandas as pd

# %%
dados = pd.read_csv('aluguel_amostra.csv', sep=';')
dados.head(10)
# Out:
#           Tipo                    Bairro  Quartos  Vagas  Suites  Area  \
# 0  Apartamento  Recreio dos Bandeirantes        3      2       1   320
# 1  Apartamento                  Maracanã        2      0       0    59
# 2  Apartamento                    Leblon        3      2       1   147
# 3  Apartamento               São Conrado        3      3       3   270
# 4  Apartamento                    Tijuca        2      1       0    65
# 5  Apartamento                  Cachambi        2      1       1    75
# 6  Apartamento                    Glória        1      0       0    52
# 7  Apartamento              Engenho Novo        2      1       0    70
# 8  Apartamento                  Maracanã        1      1       0    59
# 9  Apartamento                  Flamengo        3      0       0   100
#
#      Valor  Condominio    IPTU  Valor m2 Tipo Agregado
# 0   3200.0      1319.0     0.0     10.00   Apartamento
# 1    800.0       725.0    47.0     13.56   Apartamento
# ...

# %%
dados.boxplot(['Valor m2'])
# Out:
# <Axes: >

# %%
valor = dados['Valor m2']
valor
# Out:
# 0       10.00
# 1       13.56
# 2       51.02
# 3       55.55
# 4       18.46
#         ...
# 9995    96.88
# 9996    31.58
# 9997    40.00
# 9998    34.00
# 9999     8.33
# Name: Valor m2, Length: 10000, dtype: float64

# %%
Q1 = valor.quantile(.25)
Q3 = valor.quantile(.75)
IIQ = Q3 - Q1
limite_inferior = Q1 - 1.5 * IIQ
limite_superior = Q3 + 1.5 * IIQ

# %%
print(f'{Q1=}')
print(f'{Q3=}')
print(f'{IIQ.round(2)=}')
print(f'{limite_inferior.round(2)=}')
print(f'{limite_superior.round(2)=}')
# Out:
# Q1=21.25
# Q3=42.31
# IIQ.round(2)=21.06
# limite_inferior.round(2)=-10.34
# limite_superior.round(2)=73.9

# %%
selection = (valor >= limite_inferior) & (valor <= limite_superior)
dados_new = dados[selection]

# %%
dados_new.boxplot(['Valor m2'])
# Out:
# <Axes: >

# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
plt.rc('figure', figsize = (15, 7))

dados = pd.read_csv('aluguel_amostra.csv', sep = ';')

# %%
dados
# Out:
#              Tipo                    Bairro  Quartos  Vagas  Suites  Area  \
# 0     Apartamento  Recreio dos Bandeirantes        3      2       1   320
# 1     Apartamento                  Maracanã        2      0       0    59
# 2     Apartamento                    Leblon        3      2       1   147
# 3     Apartamento               São Conrado        3      3       3   270
# 4     Apartamento                    Tijuca        2      1       0    65
# ...           ...                       ...      ...    ...     ...   ...
# 9995  Apartamento                Copacabana        3      1       2   160
# 9996  Apartamento                Copacabana        4      0       0   190
# 9997  Apartamento           Barra da Tijuca        2      1       1    70
# 9998  Apartamento                    Tijuca        1      0       0    50
# 9999  Apartamento  Recreio dos Bandeirantes        3      2       1   300
#
#         Valor  Condominio    IPTU  Valor m2 Tipo Agregado
# ...

# %%
area = plt.figure()
g1 = area.add_subplot(1, 2, 1)
g2 = area.add_subplot(1, 2, 2)
grupo1 = dados.groupby('Tipo Agregado')['Valor']
label = grupo1.count().index
valores = grupo1.count().values
g1.pie(valores, labels = label, autopct='%1.1f%%')
g1.set_title('Total de Imóveis por Tipo Agregado')
grupo2 = dados.groupby('Tipo')['Valor']
label = grupo2.count().index
valores = grupo2.count().values
g2.pie(valores, labels = label, autopct='%1.1f%%', explode = (.1, .1, .1, .1, .1))
g2.set_title('Total de Imóveis por Tipo')
# Out:
# Text(0.5, 1.0, 'Total de Imóveis por Tipo')
